# %%
from dataset import HeatSourceDataset
from model import UNet
import torch

ds = HeatSourceDataset('data/train.npz')
T, Q = ds[0]
print("T shape:", T.shape)   # should be (1, 64, 64)
print("Q shape:", Q.shape)   # should be (1, 64, 64)

model = UNet()
out = model(T.unsqueeze(0))  # add batch dim
print("Output shape:", out.shape)  # should be (1, 1, 64, 64)
print("Model parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# T shape: torch.Size([1, 64, 64])
# Q shape: torch.Size([1, 64, 64])
# Output shape: torch.Size([1, 1, 64, 64])
# Model parameters: 7765409

# %%
import os
os.chdir(r'C:\Users\Test\inverse-heat-transfer')
exec(open('train.py').read())
# Out:
# Training on: cpu
# Epoch   1/50 | Train: 17544.178602 | Val: 0.063886 | Best: 0.063886
# Epoch   5/50 | Train: 17544.176633 | Val: 0.061663 | Best: 0.061381
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import os
#       2 os.chdir(r'C:\Users\Test\inverse-heat-transfer')
# ----> 3 exec(open('train.py').read())
#
# File <string>:60
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
# ...
